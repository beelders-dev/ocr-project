# %%
# %pip install -q transformers datasets paddlepaddle paddleocr torch torchvision
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.7/80.7 kB 2.0 MB/s eta 0:00:00a 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 3.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.9/42.9 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 MB 8.2 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.8/146.8 kB 10.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 69.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 759.5/759.5 kB 38.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.7/68.7 MB 11.9 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 4.0 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# Update this path to match where your project folder lives in Drive
# %cd /content/drive/MyDrive/ocr_project
# Out:
# Mounted at /content/drive
# [Errno 2] No such file or directory: '/content/drive/MyDrive/ocr_project'
# /content

# %%
import torch
print("Using GPU:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU detected")

# !python -m src.dataset_generator
# !python -m src.train
# Out:
# Using GPU: Tesla T4
# /usr/bin/python3: Error while finding module specification for 'src.dataset_generator' (ModuleNotFoundError: No module named 'src')
# /usr/bin/python3: Error while finding module specification for 'src.train' (ModuleNotFoundError: No module named 'src')

# %%
import shutil
from google.colab import files

shutil.make_archive('model_output', 'zip', 'output/')
files.download('model_output.zip')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1420/4289532325.py in <cell line: 0>()
#       2 from google.colab import files
#       3
# ----> 4 shutil.make_archive('model_output', 'zip', 'output/')
#       5 files.download('model_output.zip')
#
# /usr/lib/python3.13/shutil.py in make_archive(base_name, format, root_dir, base_dir, verbose, dry_run, owner, group, logger)
#    1155     save_cwd = None
#    1156     if root_dir is not None:
# -> 1157         stmd = os.stat(root_dir).st_mode
#    1158         if not stat.S_ISDIR(stmd):
#    1159             raise NotADirectoryError(errno.ENOTDIR, 'Not a directory', root_dir)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output/'

# %%
import os
print("Current Working Directory Contents:", os.listdir())
# Out:
# Current Working Directory Contents: ['.config', 'sample_data']

# %%
import os
from google.colab import drive

# 1. Mount Google Drive
drive.mount('/content/drive')

# 2. List the folders inside your Google Drive to see your project folder name
print("Drive Folders:", os.listdir('/content/drive/MyDrive'))
# Out:
# Mounted at /content/drive
# ...

# %%
# Replace 'ocr_project' with your actual folder name shown in Step 1
# %cd /content/drive/MyDrive/ocr_project

# Verify your 'src' directory is present
print("Project Directory Contents:", os.listdir())
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/ocr_project'
# /content
# Project Directory Contents: ['.config', 'drive', 'sample_data']
